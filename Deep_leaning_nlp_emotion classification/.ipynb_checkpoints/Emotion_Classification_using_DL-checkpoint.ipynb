# %%
import pandas as pd
import numpy as np
import nltk
import spacy
import gensim
import warnings
warnings.filterwarnings("ignore")

# %%
# DATA IMPORTING

# %%
test_df = pd.read_csv(
    r"C:\Users\Lenovo\Desktop\github projects\nlp rnn assingment\data train test validate\test.txt",
    sep=";",
    names=["text", "emotion"]
)
train_df = pd.read_csv(
    r"C:\Users\Lenovo\Desktop\github projects\nlp rnn assingment\data train test validate\train.txt",
    sep=";",
    names=["text", "emotion"]
)
val_df = pd.read_csv(
    r"C:\Users\Lenovo\Desktop\github projects\nlp rnn assingment\data train test validate\val.txt",
    sep=";",
    names=["text", "emotion"]
)

# %%
print(test_df.head())
print("\n")
print(train_df.head())
print("\n")
print(train_df.head())
# Out:
#                                                 text  emotion
# 0  im feeling rather rotten so im not very ambiti...  sadness
# 1          im updating my blog because i feel shitty  sadness
# 2  i never make her separate from me because i do...  sadness
# 3  i left with my bouquet of red and yellow tulip...      joy
# 4    i was feeling a little vain when i did this one  sadness
#
#
#                                                 text  emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger
#
#
#                                                 text  emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
 # checking for missing values
for name,df in [("Train",train_df),("Test",test_df),("valadition", val_df)]:
    print(f"\n{name} Dataset")
    print(df.isnull().sum())
# Out:
# Train Dataset
# text       0
# emotion    0
# dtype: int64
#
# Test Dataset
# text       0
# emotion    0
# dtype: int64
#
# valadition Dataset
# text       0
# emotion    0
# dtype: int64

# %%
# checking for duplicate values

# %%
for name ,df in [("Train",train_df),("Test",test_df),("validate",val_df)]:
    print(f"\n{name} Dataset")
    print(df.duplicated().sum())
# Out:
# Train Dataset
# 1
#
# Test Dataset
# 0
#
# validate Dataset
# 0

# %%
# Basic Preprocessing 
import re 

def clean_text(text):
    text=text.lower()

    text=re.sub(r'http\S+|www\S+','',text)

    text=re.sub(r'<.*?>', '', text)

    text=re.sub(r'[^a-zA-Z\s]', '', text)

    text=re.sub(r'\s+',' ',text).strip()

    return text

# %%
train_df["clean_text"]=train_df["text"].apply(clean_text)
test_df["clean_text"]=test_df["text"].apply(clean_text)
val_df["clean_text"]=val_df["text"].apply(clean_text)

# %%
for head in [ train_df,test_df,val_df]:
    print(display(head[["text","clean_text"]].head()))
    print("--"*50)
# Out:
#                                                 text  \
# 0                            i didnt feel humiliated
# 1  i can go from feeling so hopeless to so damned...
# 2   im grabbing a minute to post i feel greedy wrong
# 3  i am ever feeling nostalgic about the fireplac...
# 4                               i am feeling grouchy
#
#                                           clean_text
# 0                            i didnt feel humiliated
# 1  i can go from feeling so hopeless to so damned...
# 2   im grabbing a minute to post i feel greedy wrong
# 3  i am ever feeling nostalgic about the fireplac...
# 4                               i am feeling grouchy
# None
# ----------------------------------------------------------------------------------------------------
#                                                 text  \
# 0  im feeling rather rotten so im not very ambiti...
# 1          im updating my blog because i feel shitty
# 2  i never make her separate from me because i do...
# 3  i left with my bouquet of red and yellow tulip...
# 4    i was feeling a little vain when i did this one
#
#                                           clean_text
# 0  im feeling rather rotten so im not very ambiti...
# 1          im updating my blog because i feel shitty
# 2  i never make her separate from me because i do...
# 3  i left with my bouquet of red and yellow tulip...
# 4    i was feeling a little vain when i did this one
# None
# ----------------------------------------------------------------------------------------------------
#                                                 text  \
# 0  im feeling quite sad and sorry for myself but ...
# 1  i feel like i am still looking at a blank canv...
# 2                     i feel like a faithful servant
# 3                  i am just feeling cranky and blue
# 4  i can have for a treat or if i am feeling festive
#
#                                           clean_text
# 0  im feeling quite sad and sorry for myself but ...
# 1  i feel like i am still looking at a blank canv...
# 2                     i feel like a faithful servant
# 3                  i am just feeling cranky and blue
# 4  i can have for a treat or if i am feeling festive
# None
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Tokenization

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer=Tokenizer(num_words=10000,oov_token="<OOV>")
tokenizer.fit_on_texts(train_df["clean_text"])

# %%
X_train=tokenizer.texts_to_sequences(train_df["clean_text"])
X_test=tokenizer.texts_to_sequences(test_df["clean_text"])
X_val=tokenizer.texts_to_sequences(val_df["clean_text"])

# %%
# Label Encododint(Target Variabel)
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()

# %%
y_train=label_encoder.fit_transform(train_df["emotion"])
y_test=label_encoder.transform(test_df["emotion"])
y_val=label_encoder.transform(val_df["emotion"])

# %%
label_encoder.classes_
# Out:
# array(['anger', 'fear', 'joy', 'love', 'sadness', 'surprise'],
#       dtype=object)

# %%
#### Padding 
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
max_length=60

X_train=pad_sequences(X_train,maxlen=max_length,padding='post',truncating='post')
X_test=pad_sequences(X_test,maxlen=max_length,padding='post',truncating='post')
X_val=pad_sequences(X_val,maxlen=max_length,padding='post',truncating='post')

# %% [markdown]
# # MODELLING

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Embedding,SimpleRNN,LSTM,GRU,Dense,Dropout,Bidirectional)
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import (classification_report,confusion_matrix,accuracy_score)

# %%
vocab_size=len(tokenizer.word_index)+1

max_length=X_train.shape[1]

num_classes=len(label_encoder.classes_)

embedding_dim=128

# %% [markdown]
# # EVALUATION FUNCTION

# %%
def evaluate_model(model,X_train,y_train,X_test,y_test):
    # Train Predictions 
    train_pred=model.predict(X_train,verbose=0)
    train_pred_classes=np.argmax(train_pred,axis=1)

    #Test Predictions
    test_pred=model.predict(X_test,verbose=0)
    test_pred_classes=np.argmax(test_pred,axis=1)

    #ACCURACY
    train_acc=accuracy_score(y_train,train_pred_classes)
    test_acc=accuracy_score(y_test,test_pred_classes)

    #cofusion Matrix 
    cm=confusion_matrix(y_test,test_pred_classes)
    #classification_report 
    report=classification_report(y_test,test_pred_classes)

    print("MODEL EVALUATION")
    print("="*50)

    print(f"\n Train Accuracy :{train_acc}")
    print(f"\n Test Accuracy :{test_acc}")

    print("\n Classification Report")
    print(report)

    print("\n Confusion Matrix")
    print(cm)

# %% [markdown]
# ### 1.Simple RNN

# %%
rnn_model=Sequential([Embedding(input_dim=vocab_size,output_dim=embedding_dim,input_length=max_length),
                      SimpleRNN(128),Dense(num_classes,activation='softmax')])

rnn_model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
rnn_model.build(input_shape=(None, max_length))

rnn_model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)         │ (None, 60, 128)        │     1,947,008 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_5 (SimpleRNN)        │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,980,678 (7.56 MB)
#  Trainable params: 1,980,678 (7.56 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_rnn=rnn_model.fit(X_train,y_train,validation_data=(X_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 22s 40ms/step - accuracy: 0.3214 - loss: 1.5983 - val_accuracy: 0.3520 - val_loss: 1.5828
# Epoch 2/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.3223 - loss: 1.5890 - val_accuracy: 0.3465 - val_loss: 1.5869
# Epoch 3/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 0.3275 - loss: 1.5818 - val_accuracy: 0.2820 - val_loss: 1.5943
# Epoch 4/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 19s 39ms/step - accuracy: 0.3329 - loss: 1.5779 - val_accuracy: 0.3515 - val_loss: 1.5826
# Epoch 5/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 19s 38ms/step - accuracy: 0.3302 - loss: 1.5853 - val_accuracy: 0.3425 - val_loss: 1.5903
# Epoch 6/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 35ms/step - accuracy: 0.3266 - loss: 1.5801 - val_accuracy: 0.2800 - val_loss: 1.5887
# Epoch 7/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 19s 39ms/step - accuracy: 0.3369 - loss: 1.5759 - val_accuracy: 0.2735 - val_loss: 1.5971
# Epoch 8/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 0.3365 - loss: 1.5746 - val_accuracy: 0.3355 - val_loss: 1.6000
# Epoch 9/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.3376 - loss: 1.5729 - val_accuracy: 0.3150 - val_loss: 1.5935
# Epoch 10/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 19s 38ms/step - accuracy: 0.3339 - loss: 1.5742 - val_accuracy: 0.2755 - val_loss: 1.6200

# %%
evaluate_model(rnn_model,X_train,y_train,X_test,y_test)
# Out:
# MODEL EVALUATION
# ==================================================
#
#  Train Accuracy :0.301
#
#  Test Accuracy :0.289
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       275
#            1       0.00      0.00      0.00       224
#            2       0.20      0.00      0.01       695
#            3       0.00      0.00      0.00       159
#            4       0.29      0.99      0.45       581
#            5       0.00      0.00      0.00        66
#
#     accuracy                           0.29      2000
#    macro avg       0.08      0.17      0.08      2000
# weighted avg       0.15      0.29      0.13      2000
#
#
#  Confusion Matrix
# [[  0   0   2   0 273   0]
#  [  0   0   0   0 224   0]
#  [  0   0   2   0 693   0]
#  [  0   0   0   0 159   0]
#  [  0   0   5   0 576   0]
#  [  0   0   1   0  65   0]]

# %% [markdown]
# ### 2. LSTM

# %%
lstm_model=Sequential([Embedding(input_dim=vocab_size,output_dim=embedding_dim,input_length=max_length),LSTM(128),
                       Dense(num_classes,activation='softmax')])
lstm_model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
lstm_model.build(input_shape=(None, max_length))
lstm_model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_7 (Embedding)         │ (None, 60, 128)        │     1,947,008 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,079,366 (7.93 MB)
#  Trainable params: 2,079,366 (7.93 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_lstm=lstm_model.fit(X_train,y_train,validation_data=(X_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 32s 60ms/step - accuracy: 0.3318 - loss: 1.5830 - val_accuracy: 0.3520 - val_loss: 1.5817
# Epoch 2/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 31s 63ms/step - accuracy: 0.3345 - loss: 1.5775 - val_accuracy: 0.3520 - val_loss: 1.5828
# Epoch 3/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 31s 61ms/step - accuracy: 0.3324 - loss: 1.5765 - val_accuracy: 0.3520 - val_loss: 1.5829
# Epoch 4/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 32s 64ms/step - accuracy: 0.3330 - loss: 1.5704 - val_accuracy: 0.3515 - val_loss: 1.5014
# Epoch 5/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 31s 63ms/step - accuracy: 0.4610 - loss: 1.1492 - val_accuracy: 0.5825 - val_loss: 0.9155
# Epoch 6/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 31s 62ms/step - accuracy: 0.6101 - loss: 0.7765 - val_accuracy: 0.6505 - val_loss: 0.7198
# Epoch 7/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 31s 62ms/step - accuracy: 0.8556 - loss: 0.4337 - val_accuracy: 0.8845 - val_loss: 0.3860
# Epoch 8/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 31s 63ms/step - accuracy: 0.9236 - loss: 0.2524 - val_accuracy: 0.9060 - val_loss: 0.3092
# Epoch 9/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 31s 62ms/step - accuracy: 0.9408 - loss: 0.1764 - val_accuracy: 0.9090 - val_loss: 0.2731
# Epoch 10/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 31s 63ms/step - accuracy: 0.9473 - loss: 0.1473 - val_accuracy: 0.9135 - val_loss: 0.2577

# %%
evaluate_model(lstm_model,X_train,y_train,X_test,y_test)
# Out:
# MODEL EVALUATION
# ==================================================
#
#  Train Accuracy :0.9574375
#
#  Test Accuracy :0.902
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       275
#            1       0.92      0.80      0.86       224
#            2       0.92      0.91      0.91       695
#            3       0.74      0.86      0.79       159
#            4       0.97      0.94      0.96       581
#            5       0.67      0.76      0.71        66
#
#     accuracy                           0.90      2000
#    macro avg       0.85      0.87      0.86      2000
# weighted avg       0.91      0.90      0.90      2000
#
#
#  Confusion Matrix
# [[255   6   6   0   7   1]
#  [ 10 180   8   0   5  21]
#  [  4   2 634  48   5   2]
#  [  2   0  19 137   1   0]
#  [ 14   3  14   1 548   1]
#  [  1   4  11   0   0  50]]

# %%
###3. GRU
